# %%
import numpy as np         # библиотека для матриц и математики
import pandas as pd        # библиотека для работы с табличками
from scipy import stats    # модуль для работы со статистикой

# библиотеки для визуализации
import matplotlib.pyplot as plt
import seaborn as sns

import math

from statsmodels.stats.weightstats import ztest as ztest

plt.style.use('ggplot')    # стиль графиков

# %matplotlib inline

# %%
#for X1
n1 = 100

sample1 = stats.chi2(2).rvs(n1) 

mean1 = np.mean(sample1)
var1 = np.var(sample1, ddof = 1)
std1 = np.std(sample1)

print("X1: mean1 = %.3f; var1 = %.3f; std1 = %.3f; n1 = %.3f" % (mean1, var1, std1, n1))
# Out:
# X1: mean1 = 2.175; var1 = 4.194; std1 = 2.038; n1 = 100.000

# %%
#for X2
n2 = 150

sample2 = stats.norm(loc=3, scale=1).rvs(n2) 

mean2 = np.mean(sample2)
var2 = np.var(sample2, ddof = 1)
std2 = np.std(sample2)

print("X2: mean2 = %.3f; var2 = %.3f; std2 = %.3f; n2 = %.3f" % (mean2, var2, std2, n2))
# Out:
# X2: mean2 = 3.197; var2 = 0.959; std2 = 0.976; n2 = 150.000

# %%
#for X3
n3 = 200

sample3 = stats.uniform(loc=-2, scale=2).rvs(n3) 

mean3 = np.mean(sample3)
var3 = np.var(sample3, ddof = 1)
std3 = np.std(sample3)

print("X3: mean3 = %.3f; var3 = %.3f; std3 = %.3f; n3 = %.3f" % (mean3, var3, std3, n3))
# Out:
# X3: mean3 = -0.975; var3 = 0.333; std3 = 0.575; n3 = 200.000

# %%
#for X4
n4 = 100

sample4 = stats.norm(loc=5, scale=1).rvs(n4) 

mean4 = np.mean(sample4)
var4 = np.var(sample4, ddof = 1)
std4 = np.std(sample4)

print("X4: mean4 = %.3f; var4 = %.3f; std4 = %.3f; n4 = %.3f" % (mean4, var4, std4, n4))
# Out:
# X4: mean4 = 4.902; var4 = 0.956; std4 = 0.973; n4 = 100.000

# %%
#Pooled for X1, X2, X3, X4

mean_pol = (n1 * mean1 + n2 * mean2 + n3 * mean3 + n4*mean4)/(n1 + n2 + n3 + n4) 
var_pol = ((n1 - 1) * var1 + (n2 - 1) * var2 + (n3 - 1) * var3 + (n4 - 1) * var4) / (n1 + n2 + n3 + n4 - 4) #вопрос
std_pol = var_pol**1/2
n_pol = n1 + n2 + n3 + n4
print("Pooled for X1, X2, X3, X4: mean_pol = %.3f; var_pol = %.3f; std_pol = %.3f; n_pol = %.3f" % (mean_pol, var_pol, std_pol, n_pol))
# Out:
# Pooled for X1, X2, X3, X4: mean_pol = 1.804; var_pol = 1.317; std_pol = 0.658; n_pol = 550.000

# %%
#plt.boxplot(sample1)
data = [sample1, sample2, sample3, sample4]

fig = plt.figure(figsize =(10, 7))
plt.boxplot(data)

# Adding title
plt.title("Box-and-Whisker")

# x-axis labels
ax.set_yticklabels(['data_1', 'data_2',
                    'data_3', 'data_4'])

plt.show()

# %%
data = [sample1, sample2, sample3, sample4]

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

bp = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00',
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")

# %%
#критерий Бартлетта
stats.bartlett(sample1, sample2, sample3, sample4)
# Out:
# BartlettResult(statistic=237.2513512885056, pvalue=3.740133931374756e-51)

# %%
#Однофакторный дисперсионный анализ
stats.f_oneway(sample1, sample2, sample3, sample4)
# Out:
# F_onewayResult(statistic=711.3621236866518, pvalue=3.897966969970542e-188)

# %%
K = 4
n = n1 + n2 + n3 + n4
mean = (sum(sample1) + sum(sample2) + sum(sample3) + sum(sample4))/n #общее среднее

#общая дисперсия
s = 0
for ar in data:
  for x in ar:
    s += (x - mean)**2
D_x = s/n

#внутригрупповая дисперсиея
s = 0
for ar in data:
  s = s + len(ar) * np.var(ar)
D_w = s/n

#межгрупповая дисперсия
s = 0
for ar in data:
  s = s + len(ar) * (np.mean(ar) - mean)**2
D_b = s/n

#print(D_x)
#print(D_w + D_b)

print("D_b = %.3f" % D_b)
print("D_w = %.3f" % D_w)
print("D_x = %.3f" % D_x)

print('Несмещенная оценка групировочного признака: {z:.3f}'.format(z = (D_b * n)/(K - 1)))
print('Несмещенная оценка остаточного признака: {z:.3f}'.format(z = (D_w * n)/(n - K)))
print('Несмещенная оценка всех признаков: {z:.3f}'.format(z = (D_x * n)/(n - 1)))
# Out:
# D_b = 5.109
# D_w = 1.307
# D_x = 6.416
# Несмещенная оценка групировочного признака: 936.661
# Несмещенная оценка остаточного признака: 1.317
# Несмещенная оценка всех признаков: 6.428

# %%
eta_squared = D_b / D_x   #эмпирический коэффициент детерминации
eta = eta_squared ** (1/2)   #эмпирическое корреляционное отношение

print("эмпирический коэффициент детерминации: %.3f" % eta_squared)
print("эмпирическое корреляционное отношение: %.3f" % eta)
# Out:
# эмпирический коэффициент детерминации: 0.796
# эмпирическое корреляционное отношение: 0.892

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from scipy.stats import f_oneway
f_oneway(sample1, sample2, sample3, sample4)

df = pd.DataFrame({'score': np.concatenate((sample1, sample2, sample3, sample4)),
                   'group': np.concatenate((np.repeat(['data_1', 'data_4'], repeats=100), np.repeat(['data_2'], repeats=150) ,np.repeat(['data_3'], repeats=200)))}) 

tukey = pairwise_tukeyhsd(endog=df['score'],
                          groups=df['group'],
                          alpha=0.05)
print(tukey)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
# data_1 data_2  -1.7672    0.0   -2.55 -0.9843   True
# data_1 data_3  -0.2057 0.8917 -0.9484   0.537  False
# data_1 data_4   1.0216  0.012   0.164  1.8792   True
# data_2 data_3   1.5615    0.0  0.9065  2.2165   True
# data_2 data_4   2.7887    0.0  2.0059  3.5716   True
# data_3 data_4   1.2273 0.0001  0.4846  1.9699   True
# ----------------------------------------------------

# %%
alpha = 0.05

c12 = mean1 - mean2
c13 = mean1 - mean3
c14 = mean1 - mean4
c23 = mean2 - mean3
c24 = mean2 - mean4
c34 = mean3 - mean4
var12 = (n * D_w) * (1/n1 + 1/n2) / (n - K)
var13 = (n * D_w) * (1/n1 + 1/n3) / (n - K)
var14 = (n * D_w) * (1/n1 + 1/n4) / (n - K)
var23 = (n * D_w) * (1/n2 + 1/n3) / (n - K)
var24 = (n * D_w) * (1/n2 + 1/n4) / (n - K)
var34 = (n * D_w) * (1/n3 + 1/n4) / (n - K)

quantile_f = stats.f(K-1,n-K).ppf(1 - alpha)

c12_lower = c12 - (var12 * (K-1) * quantile_f)**(1/2)
c13_lower = c13 - (var13 * (K-1) * quantile_f)**(1/2)
c14_lower = c14 - (var14 * (K-1) * quantile_f)**(1/2)
c23_lower = c23 - (var23 * (K-1) * quantile_f)**(1/2)
c24_lower = c24 - (var24 * (K-1) * quantile_f)**(1/2)
c34_lower = c34 - (var34 * (K-1) * quantile_f)**(1/2)

c12_upper = c12 + (var12 * (K-1) * quantile_f)**(1/2)
c13_upper = c13 + (var13 * (K-1) * quantile_f)**(1/2)
c14_upper = c14 + (var14 * (K-1) * quantile_f)**(1/2)
c23_upper = c23 + (var23 * (K-1) * quantile_f)**(1/2)
c24_upper = c24 + (var24 * (K-1) * quantile_f)**(1/2)
c34_upper = c34 + (var34 * (K-1) * quantile_f)**(1/2)

# %%
data_dict = {}
data_dict['category'] = ['C12','C13','C14','C23','C24','C34']
data_dict['lower'] = [c12_lower, c13_lower, c14_lower, c23_lower, c24_lower, c34_lower]
data_dict['upper'] = [c12_upper, c13_upper, c14_upper, c23_upper, c24_upper, c34_upper]
dataset = pd.DataFrame(data_dict)

for lower,upper,y in zip(dataset['lower'],dataset['upper'],range(len(dataset))):
    plt.plot((lower,upper),(y,y),'ro-',color='orange')
plt.yticks(range(len(dataset)),list(dataset['category']))
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9548\3998290973.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot((lower,upper),(y,y),'ro-',color='orange')
# ([<matplotlib.axis.YTick at 0x2b2055b8110>,
#   <matplotlib.axis.YTick at 0x2b2055a86d0>,
#   <matplotlib.axis.YTick at 0x2b205594410>,
#   <matplotlib.axis.YTick at 0x2b20557ebd0>,
#   <matplotlib.axis.YTick at 0x2b205573e50>,
#   <matplotlib.axis.YTick at 0x2b2030d3d90>],
#  [Text(0, 0, 'C12'),
#   Text(0, 1, 'C13'),
#   Text(0, 2, 'C14'),
#   Text(0, 3, 'C23'),
#   Text(0, 4, 'C24'),
#   Text(0, 5, 'C34')])
